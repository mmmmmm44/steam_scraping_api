# %% [markdown]
# # Find categories in main page

# %% [markdown]
# In the main page, we can see there is a 4-tab section showing games in different labels
#
# - Specials
# - Popular Upcoming
# - Top Sellers
# - New & Trending
#
# I stumbled on an article in which the author using web-scraping and HTML post-processing to extract the games and their prices
#
# However, we can use the single API to collect the games and then use the /api/appdetails API to retrieve different informations (like price, or others)
#
# Besides it also allows us to track for more games by tweaking the parameters passed to the API.

# %% [markdown]
# /search/result/ API is used to achieve the function

# %%
from datetime import datetime
import time
import requests
import pickle
from pathlib import Path
import re

# %%
def print_log(*args):
    print(f"[{str(datetime.now())[:-3]}] ", end="")
    print(*args)

# %%
def get_search_results(params):
    req_sr = requests.get(
        "https://store.steampowered.com/search/results/",
        params=params)
    
    if req_sr.status_code != 200:
        print_log(f"Failed to get search results: {req_sr.status_code}")
        return {"items": []}
    
    try:
        search_results = req_sr.json()
    except Exception as e:
        print_log(f"Failed to parse search results: {e}")
        return {"items": []}
    
    return search_results

# %%
def get_app_details(appid):
    while(True):
        if appid == None:
            print_log("App Id is None.")
            return {}

        appdetails_req = requests.get(
            "https://store.steampowered.com/api/appdetails/",
            params={"appids": appid, "cc": "hk", "l": "english"})
        
        if appdetails_req.status_code == 200:
            appdetails = appdetails_req.json()
            appdetails = appdetails[str(appid)]
            print_log(f"App Id: {appid} - {appdetails['success']}")
            break

        elif appdetails_req.status_code == 429:
            print_log(f'Too many requests. Sleep for 10 sec')
            time.sleep(10)
            continue

        elif appdetails_req.status_code == 403:
            print_log(f'Forbidden to access. Sleep for 5 min.')
            time.sleep(5 * 60)
            continue

        else:
            print_log("ERROR: status code:", appdetails_req.status_code)
            print_log(f"Error in App Id: {appid}.")
            appdetails = {}
            break

    return appdetails

# %% [markdown]
# To retrieve different search results, one can use different filter value, which can be observed by looking at the URL of the search page (i.e. store.steampowered.com/search/...)
#
# Through my observation, there are five values
# - "" (empty): default behaviour. Usually used with field "sorted_by"="Released_DESC" to retrieve the latest published games on Steam
# - "popularnew": means "Popular New Releases", correspond to "New & Trending" tab
# - "topsellers": correspond to "Top Sellers" tab. Can set whether includes free-to-play games or not
# - "globaltopsellers": correspond to "Global Top Sellers" button in the "See more:" section of the "Top Sellers" tab
# - "popularcommingsoon": correspond to "Popular Upcoming" tab
#
# For specials tab, just set the "specials" field to 1 while passing the params to the API

# %% [markdown]
# To make things simple, for each game/app in the returned result, we call the /api/appdetails once to get all the information of an application on Steam for further analysis

# %%
execute_datetime = datetime.now()

search_result_folder_path = Path(f"search_results_{execute_datetime.strftime('%Y%m%d')}")
if not search_result_folder_path.exists():
    search_result_folder_path.mkdir()

# %%
# a list of filters
params_list = [
    {"filter": "topsellers"},
    {"filter": "globaltopsellers"},
    {"filter": "popularnew"},
    {"filter": "popularcommingsoon"},
    {"filter": "", "specials": 1}
]
page_list = list(range(1, 5))

params_sr_default = {
    "filter": "topsellers",
    "hidef2p": 1,
    "page": 1,              # page is used to go through different parts of the ranking. Each page contains 25 results
    "json": 1
}

for update_param in params_list:

    items_all = []
    if update_param["filter"]:
        filename = f"{update_param['filter']}_{execute_datetime.strftime('%Y%m%d')}.pkl"
    else:
        filename = f"specials_{execute_datetime.strftime('%Y%m%d')}.pkl"

    if (search_result_folder_path / filename).exists():
        print_log(f"File {filename} exists. Skip.")
        continue

    for page_no in page_list:
        param = params_sr_default.copy()
        param.update(update_param)
        param["page"] = page_no

        search_results = get_search_results(param)
        print_log(search_results)

        if not search_results:
            continue

        items = search_results.get("items", [])

        # proprocessing search results to retrieve the appid of the game
        for item in items:
            try:
                item["appid"] = re.search(r"steam/\w+/(\d+)", item["logo"]).group(1)      # the URL can be steam/bundles/{appid} or steam/apps/{appid}
            except Exception as e:
                print_log(f"Failed to extract appid: {e}")
                item["appid"] = None

        # request for game information using appid
        for item in items:
            appid = item["appid"]
            appdetails = get_app_details(appid)
            item["appdetail"] = appdetails

        items_all.extend(items)

    # save the search results
    with open(search_result_folder_path / filename, "wb") as f:
        pickle.dump(items_all, f)
    print_log(f"Saved {filename}")
# Out:
# [2024-05-28 11:09:55.199] File topsellers_20240528.pkl exists. Skip.
# [2024-05-28 11:09:55.199] File globaltopsellers_20240528.pkl exists. Skip.
# [2024-05-28 11:09:55.199] File popularnew_20240528.pkl exists. Skip.
# [2024-05-28 11:09:55.199] File popularcommingsoon_20240528.pkl exists. Skip.
# [2024-05-28 11:09:55.632] {'desc': '', 'items': [{'name': 'Planet Coaster', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/493340/capsule_sm_120.jpg?t=1709820332'}, {'name': 'Red Dead Redemption 2', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1174180/capsule_sm_120.jpg?t=1714055653'}, {'name': 'Ready or Not', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1144200/capsule_sm_120.jpg?t=1707410886'}, {'name': "Tom Clancy's Rainbow Six® Siege", 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/359550/capsule_sm_120.jpg?t=1715902855'}, {'name': 'Total War: WARHAMMER III', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1142710/capsule_sm_120.jpg?t=1716536507'}, {'name': 'Euro Truck Simulator 2', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/227300/capsule_sm_120.jpg?t=1716524980'}, {'name': 'Grand Theft Auto V', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/271590/capsule_sm_120.jpg?t=1716224849'}, {'name': 'DAVE THE DIVER', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1868140/capsule_sm_120.jpg?t=1716447953'}, {'name': 'The Elder Scrolls® Online', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/306130/capsule_sm_120.jpg?t=1714743018'}, {'name': 'Total War: WARHAMMER II', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/594570/capsule_sm_120.jpg?t=1699976686'}, {'name': 'Planet Coaster: Complete the Collection', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/13027/vswpb79ekpybjwn7/capsule_sm_120.jpg?t=1576772269'}, {'name': 'Lobotomy Corporation | Monster Management Simulation', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/568220/capsule_sm_120.jpg?t=1636694188'}, {'name': 'Total War: Warhammer III Collection', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/34898/3jliokgulr35csow/capsule_sm_120.jpg?t=1694612221'}, {'name': 'NBA 2K24', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2338770/capsule_sm_120.jpg?t=1715964888'}, {'name': 'Total War: WARHAMMER TRILOGY', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/33257/8xwhzewtxjm1nl2p/capsule_sm_120.jpg?t=1688055705'}, {'name': 'American Truck Simulator', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/270880/capsule_sm_120.jpg?t=1716524809'}, {'name': 'Terraria', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/105600/capsule_sm_120.jpg?t=1666290860'}, {'name': 'Total War: WARHAMMER II Collection', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/27892/7sf52olq413b8pi6/capsule_sm_120.jpg?t=1665074263'}, {'name': 'Warhammer 40,000: Rogue Trader', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2186680/capsule_sm_120.jpg?t=1716801033'}, {'name': 'The Elder Scrolls V: Skyrim Special Edition', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/489830/capsule_sm_120.jpg?t=1701807334'}, {'name': 'DAVE THE DIVER Deluxe Edition', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/32958/sv4mk97vuyb8kgft/capsule_sm_120.jpg?t=1706097208'}, {'name': 'Total War: WARHAMMER', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/364360/capsule_sm_120.jpg?t=1668768531'}, {'name': 'Hunt: Showdown', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/594650/capsule_sm_120.jpg?t=1715186027'}, {'name': "Tom Clancy's Ghost Recon® Breakpoint", 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2231380/capsule_sm_120.jpg?t=1697654010'}, {'nam ...
# [2024-05-28 11:09:56.528] App Id: 493340 - True
# [2024-05-28 11:09:56.890] App Id: 1174180 - True
# [2024-05-28 11:09:57.264] App Id: 1144200 - True
# [2024-05-28 11:09:57.776] App Id: 359550 - True
# [2024-05-28 11:09:58.420] App Id: 1142710 - True
# [2024-05-28 11:09:58.864] App Id: 227300 - True
# [2024-05-28 11:09:59.519] App Id: 271590 - True
# [2024-05-28 11:09:59.877] App Id: 1868140 - True
# [2024-05-28 11:10:00.293] App Id: 306130 - True
# [2024-05-28 11:10:00.632] App Id: 594570 - True
# [2024-05-28 11:10:00.975] App Id: 13027 - False
# [2024-05-28 11:10:01.299] App Id: 568220 - True
# [2024-05-28 11:10:01.617] App Id: 34898 - False
# [2024-05-28 11:10:01.965] App Id: 2338770 - True
# [2024-05-28 11:10:02.334] App Id: 33257 - False
# [2024-05-28 11:10:02.707] App Id: 270880 - True
# [2024-05-28 11:10:03.701] App Id: 105600 - True
# [2024-05-28 11:10:04.021] App Id: 27892 - False
# [2024-05-28 11:10:04.569] App Id: 2186680 - True
# [2024-05-28 11:10:05.224] App Id: 489830 - True
# [2024-05-28 11:10:05.520] App Id: 32958 - False
# [2024-05-28 11:10:05.884] App Id: 364360 - True
# [2024-05-28 11:10:06.728] App Id: 594650 - True
# [2024-05-28 11:10:07.320] App Id: 2231380 - True
# [2024-05-28 11:10:07.669] App Id: 1623730 - True
# [2024-05-28 11:10:08.144] {'desc': '', 'items': [{'name': 'Project Zomboid', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/108600/capsule_sm_120.jpg?t=1691508011'}, {'name': 'The Forest', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/242760/capsule_sm_120.jpg?t=1699381053'}, {'name': 'Warhammer 40,000: Rogue Trader - Voidfarer Edition', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/36542/stzipuxha4pr55a4/capsule_sm_120.jpg?t=1700756336'}, {'name': 'Days Gone', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1259420/capsule_sm_120.jpg?t=1698779323'}, {'name': 'Train Sim World® 4', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2362300/capsule_sm_120_alt_assets_0.jpg?t=1716233016'}, {'name': 'Grand Theft Auto V: Premium Edition & Great White Shark Card Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/5700/h06r2tta6hqg9iha/capsule_sm_120.jpg?t=1670346465'}, {'name': 'Great Plains Calling! Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/33975/1039v68pmtzqk4ni/capsule_sm_120.jpg?t=1715878699'}, {'name': "No Man's Sky", 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/275850/capsule_sm_120_alt_assets_21.jpg?t=1711607335'}, {'name': 'Esports Godfather', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1278540/capsule_sm_120.jpg?t=1716509174'}, {'name': 'Besiege', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/346010/capsule_sm_120_alt_assets_5.jpg?t=1716809117'}, {'name': 'SCUM Complete Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/33035/eucskagds2n0q1ba/capsule_sm_120.jpg?t=1712228662'}, {'name': 'Enshrouded', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1203620/capsule_sm_120.jpg?t=1715949359'}, {'name': 'Rust', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/252490/capsule_sm_120.jpg?t=1715591843'}, {'name': 'Borderlands 3', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/397540/capsule_sm_120.jpg?t=1693524259'}, {'name': 'Warhammer 40,000: Darktide', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1361210/capsule_sm_120_alt_assets_9.jpg?t=1716477180'}, {'name': 'Total War: THREE KINGDOMS COLLECTION', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/21160/n8yf8gtfw3v7xslz/capsule_sm_120.jpg?t=1716294028'}, {'name': 'The Rogue Prince of Persia', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2717880/capsule_sm_120.jpg?t=1716832160'}, {'name': 'Grand Theft Auto V: Premium Edition', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/5699/qipqf90z2z7h4x3i/capsule_sm_120.jpg?t=1678931390'}, {'name': 'The Planet Crafter', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1284190/capsule_sm_120_alt_assets_6.jpg?t=1716830464'}, {'name': 'Far Cry® 5', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/552520/capsule_sm_120.jpg?t=1694554810'}, {'name': 'Dusk Pub', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1974520/capsule_sm_120.jpg?t=1715785278'}, {'name': 'Total War: WARHAMMER Collection', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/22721/108pdz5fhg863ux7/capsule_sm_120.jpg?t=1632416272'}, {'name': 'Middle-earth™: Shadow of War™', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/356190/capsule_sm_120.jpg?t=1575317164'}, {'name': "Assassin's Creed® Unity", 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/289650/capsule_sm_120.jpg? ...
# [2024-05-28 11:10:08.508] App Id: 108600 - True
# [2024-05-28 11:10:09.092] App Id: 242760 - True
# [2024-05-28 11:10:09.427] App Id: 36542 - False
# [2024-05-28 11:10:10.328] App Id: 1259420 - True
# [2024-05-28 11:10:10.963] App Id: 2362300 - True
# [2024-05-28 11:10:11.294] App Id: 5700 - True
# [2024-05-28 11:10:11.641] App Id: 33975 - False
# [2024-05-28 11:10:12.009] App Id: 275850 - True
# [2024-05-28 11:10:12.431] App Id: 1278540 - True
# [2024-05-28 11:10:12.956] App Id: 346010 - True
# [2024-05-28 11:10:13.542] App Id: 33035 - False
# [2024-05-28 11:10:14.067] App Id: 1203620 - True
# [2024-05-28 11:10:14.659] App Id: 252490 - True
# [2024-05-28 11:10:15.014] App Id: 397540 - True
# [2024-05-28 11:10:15.612] App Id: 1361210 - True
# [2024-05-28 11:10:15.910] App Id: 21160 - False
# [2024-05-28 11:10:16.242] App Id: 2717880 - True
# [2024-05-28 11:10:16.538] App Id: 5699 - False
# [2024-05-28 11:10:16.856] App Id: 1284190 - True
# [2024-05-28 11:10:17.234] App Id: 552520 - True
# [2024-05-28 11:10:17.605] App Id: 1974520 - True
# [2024-05-28 11:10:17.924] App Id: 22721 - False
# [2024-05-28 11:10:18.264] App Id: 356190 - True
# [2024-05-28 11:10:18.627] App Id: 289650 - True
# [2024-05-28 11:10:19.404] App Id: 10076 - False
# [2024-05-28 11:10:19.773] {'desc': '', 'items': [{'name': 'Metro Exodus', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/412020/capsule_sm_120.jpg?t=1706778291'}, {'name': 'Sons Of The Forest', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1326470/capsule_sm_120.jpg?t=1708624856'}, {'name': 'Minecraft Dungeons', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1672970/capsule_sm_120.jpg?t=1715792276'}, {'name': 'Content Warning', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2881650/capsule_sm_120.jpg?t=1715689548'}, {'name': 'Batman: Arkham Collection', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/subs/320795/capsule_sm_120.jpg?t=1636658684'}, {'name': 'Total War: WARHAMMER III - Shadows of Change', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2325830/capsule_sm_120.jpg?t=1708614224'}, {'name': 'I Expect You To Die Trilogy Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/29857/jkit4zbomqzy6jfb/capsule_sm_120.jpg?t=1700683756'}, {'name': 'Kuroinu Series Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/36899/9m9dvtqn5xgb6gdz/capsule_sm_120.jpg?t=1701225300'}, {'name': 'Batman™: Arkham Knight', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/208650/capsule_sm_120.jpg?t=1702934528'}, {'name': 'REMNANT II®', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1282100/capsule_sm_120.jpg?t=1713896585'}, {'name': 'Myth of Empires', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1371580/capsule_sm_120.jpg?t=1711755798'}, {'name': 'Mediterranean Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/35839/1t5grj6xld0vb7et/capsule_sm_120.jpg?t=1698074422'}, {'name': '魔女的夜宴', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2458530/capsule_sm_120.jpg?t=1690430359'}, {'name': 'Utawarerumono Complete Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/12645/s1s982u89htlkhbe/capsule_sm_120.jpg?t=1611301765'}, {'name': 'Warhammer: Vermintide 2', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/552500/capsule_sm_120_alt_assets_23.jpg?t=1716480548'}, {'name': 'Warhammer 40,000: Rogue Trader - Season Pass', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2687230/capsule_sm_120.jpg?t=1716485666'}, {'name': 'Total War: WARHAMMER III - Forge of the Chaos Dwarfs', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2059190/capsule_sm_120.jpg?t=1710158753'}, {'name': 'The Quintessential Quintuplets - Memories of a Quintessential Summer', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2507610/capsule_sm_120.jpg?t=1716797294'}, {'name': 'Forza Horizon 5 Premium Add-Ons Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/21685/w04owynwzuscuexv/capsule_sm_120.jpg?t=1680119420'}, {'name': 'Valheim', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/892970/capsule_sm_120_alt_assets_3.jpg?t=1715688279'}, {'name': 'Nukitashi Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/37676/10z858xnaqiuiqed/capsule_sm_120.jpg?t=1708045771'}, {'name': 'Slay the Spire', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/646570/capsule_sm_120.jpg?t=1712773871'}, {'name': 'The Quintessential Quintuplets - Five Memories Spent With You', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2507620/capsule_sm_120.jpg?t=1716797342'}, {'name': 'Warhammer 40,000: Space Marine - Anniversary Edition', 'logo': 'https:// ...
# [2024-05-28 11:10:20.131] App Id: 412020 - True
# [2024-05-28 11:10:20.455] App Id: 1326470 - True
# [2024-05-28 11:10:21.019] App Id: 1672970 - True
# [2024-05-28 11:10:21.378] App Id: 2881650 - True
# [2024-05-28 11:10:21.679] App Id: 320795 - False
# [2024-05-28 11:10:22.025] App Id: 2325830 - True
# [2024-05-28 11:10:22.351] App Id: 29857 - False
# [2024-05-28 11:10:22.664] App Id: 36899 - False
# [2024-05-28 11:10:23.042] App Id: 208650 - True
# [2024-05-28 11:10:23.408] App Id: 1282100 - True
# [2024-05-28 11:10:24.031] App Id: 1371580 - True
# [2024-05-28 11:10:24.348] App Id: 35839 - False
# [2024-05-28 11:10:25.721] App Id: 2458530 - True
# [2024-05-28 11:10:26.047] App Id: 12645 - False
# [2024-05-28 11:10:26.415] App Id: 552500 - True
# [2024-05-28 11:10:26.743] App Id: 2687230 - True
# [2024-05-28 11:10:27.181] App Id: 2059190 - True
# [2024-05-28 11:10:27.519] App Id: 2507610 - True
# [2024-05-28 11:10:27.901] App Id: 21685 - False
# [2024-05-28 11:10:28.295] App Id: 892970 - True
# [2024-05-28 11:10:28.620] App Id: 37676 - False
# [2024-05-28 11:10:28.988] App Id: 646570 - True
# [2024-05-28 11:10:29.340] App Id: 2507620 - True
# [2024-05-28 11:10:29.719] App Id: 55150 - True
# [2024-05-28 11:10:30.082] App Id: 264710 - True
# [2024-05-28 11:10:30.471] {'desc': '', 'items': [{'name': "Tiny Tina's Wonderlands Chaotic Great Edition", 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/38150/qy0j86k6zcgen6dc/capsule_sm_120.jpg?t=1706551434'}, {'name': ' Shimobashira Workshop Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/25631/nmpbv42d12ieh324/capsule_sm_120.jpg?t=1715400094'}, {'name': 'Taboo Trial', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2455060/capsule_sm_120.jpg?t=1712838579'}, {'name': 'Besiege: The Splintered Sea', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2165710/capsule_sm_120.jpg?t=1716809138'}, {'name': 'Subnautica: Below Zero', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/848450/capsule_sm_120.jpg?t=1700522327'}, {'name': 'Detroit: Become Human', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1222140/capsule_sm_120.jpg?t=1667468479'}, {'name': 'Rising Storm 2: Vietnam - Complete Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/6395/2fkitlsi4ywicpso/capsule_sm_120.jpg?t=1552423864'}, {'name': 'Planet Coaster: Ghostbusters™', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1092880/capsule_sm_120.jpg?t=1617973155'}, {'name': 'Middle-earth™: The Shadow Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/subs/648168/capsule_sm_120.jpg?t=1636669603'}, {'name': 'Outer Wilds', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/753640/capsule_sm_120.jpg?t=1715873620'}, {'name': 'RAILROADS Online! - Complete the Set Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/22372/sdp6t6f5xr8716qq/capsule_sm_120.jpg?t=1630480055'}, {'name': 'Gloomhaven Gold Edition', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/26143/z6omffnmpvl3dpg7/capsule_sm_120.jpg?t=1695024125'}, {'name': 'Shin Megami Tensei III Nocturne HD Remaster', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1413480/capsule_sm_120.jpg?t=1688115589'}, {'name': 'Outer Wilds - Archaeologist Edition', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/22795/fytew9hz28f9udt5/capsule_sm_120.jpg?t=1632845002'}, {'name': ' Warhammer 40,000: Dawn of War Franchise Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/22788/5wd3im03syub73dq/capsule_sm_120.jpg?t=1632416215'}, {'name': 'Granblue Fantasy Versus: Rising', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/2157560/capsule_sm_120.jpg?t=1716458321'}, {'name': 'DOOM Franchise Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/15366/bpy5kcwk5k69vio6/capsule_sm_120.jpg?t=1660171951'}, {'name': "Tiny Tina's Wonderlands", 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1286680/capsule_sm_120.jpg?t=1682006912'}, {'name': 'TROUBLESHOOTER: Complete Collection', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/33628/mlwehe2n5recj5ky/capsule_sm_120.jpg?t=1692588789'}, {'name': 'Pumping Sunset Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/41571/yp15f9gqgrpfelng/capsule_sm_120.jpg?t=1715618622'}, {'name': 'Stray', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/apps/1332010/capsule_sm_120.jpg?t=1715873569'}, {'name': 'Sweet Memories Bundle', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/37536/1rljikk2s2b4a8pc/capsule_sm_120.jpg?t=1704499307'}, {'name': 'Galacticare: Placebo Edition', 'logo': 'https://shared.cloudflare.steamstatic.com/store_item_assets/steam/bundles/41582/ii4f3ne55g831v88/ca ...
# [2024-05-28 11:10:30.796] Too many requests. Sleep for 10 sec
# [2024-05-28 11:10:41.138] App Id: 38150 - True
# [2024-05-28 11:10:41.489] App Id: 25631 - False
# [2024-05-28 11:10:42.301] App Id: 2455060 - True
# [2024-05-28 11:10:42.654] App Id: 2165710 - True
# [2024-05-28 11:10:43.041] App Id: 848450 - True
# [2024-05-28 11:10:43.370] App Id: 1222140 - True
# [2024-05-28 11:10:43.694] App Id: 6395 - False
# [2024-05-28 11:10:44.031] App Id: 1092880 - True
# [2024-05-28 11:10:44.335] App Id: 648168 - False
# [2024-05-28 11:10:44.684] App Id: 753640 - True
# [2024-05-28 11:10:45.021] App Id: 22372 - False
# [2024-05-28 11:10:45.588] App Id: 26143 - False
# [2024-05-28 11:10:45.939] App Id: 1413480 - True
# [2024-05-28 11:10:46.279] App Id: 22795 - False
# [2024-05-28 11:10:46.585] App Id: 22788 - False
# [2024-05-28 11:10:46.926] App Id: 2157560 - True
# [2024-05-28 11:10:47.237] App Id: 15366 - False
# [2024-05-28 11:10:47.613] App Id: 1286680 - True
# [2024-05-28 11:10:47.950] App Id: 33628 - False
# [2024-05-28 11:10:48.280] App Id: 41571 - False
# [2024-05-28 11:10:48.641] App Id: 1332010 - True
# [2024-05-28 11:10:48.973] App Id: 37536 - False
# [2024-05-28 11:10:49.289] App Id: 41582 - False
# [2024-05-28 11:10:49.627] App Id: 653530 - True
# [2024-05-28 11:10:49.998] App Id: 1295500 - True
# [2024-05-28 11:10:50.005] Saved specials_20240528.pkl

# %% [markdown]
# ## Read search results of a particular date

# %%
date_to_read = datetime(2024, 5, 28)

items_listlist = []

for file in search_result_folder_path.iterdir():
    if file.suffix == ".pkl":
        date = datetime.strptime(file.stem.split("_")[-1], "%Y%m%d")
        if date == date_to_read:
            with open(file, "rb") as f:
                items = pickle.load(f)
            print_log(f"Read {file}")
            items_listlist.append(items)
# Out:
# [2024-05-28 11:17:42.246] Read search_results/topsellers_20240528.pkl
# [2024-05-28 11:17:42.250] Read search_results/popularcommingsoon_20240528.pkl
# [2024-05-28 11:17:42.252] Read search_results/specials_20240528.pkl
# [2024-05-28 11:17:42.255] Read search_results/globaltopsellers_20240528.pkl
# [2024-05-28 11:17:42.259] Read search_results/popularnew_20240528.pkl
